# %%
import matplotlib.pyplot as plt 

import matplotlib.gridspec as gridspec

import numpy as np

# %%
plt.figure(figsize=(6, 4))
G = gridspec.GridSpec(3, 3)

x = np.linspace(0, 2*np.pi, 50, endpoint=True)


#Creating Function
f1 = 2.9*np.cos(x)
f2 = 5.7*np.sin(x)
f3 = 0.5*np.sin(x)

axes_1 = plt.subplot(G[0, :])
axes_1.plot(x, f1, 'r-', x, f2)

axes_2 = plt.subplot(G[1, :-1])
axes_2.plot( x, f3)

axes_3 = plt.subplot(G[1, :-1])
axes_3.plot([1, 2, 3, 4], [1, 10, 100, 1000], 'b-')

axes_4 = plt.subplot(G[0, :])
axes_4.plot([1,2,3,4], [47, 11, 42, 60], 'r-')

axes_5 = plt.subplot(G[-1,-2])
axes_5.plot([1,2,3,4], [7, 5, 4, 3.8])

plt.tight_layout()

plt.show()

# %%
x = 50
if x < 10: 
    print("Smallar")
if x > 20:
    print("Bigger")
# Out:
# Bigger

# %%
fig = plt.figure()
x = [1, 2, 3, 4, 5, 6]
y = [1, 3, 4, 5, 7, 9]

axes1 = fig.add_axes([0.1, 0.1, 0.9, 0.9])
axes2 = fig.add_axes([0.2, 0.6, 0.4, 0.3])

axes1.plot(x, y, 'r')
axes1.set_xlabel('x-values')
axes1.set_ylabel('y-values')
axes1.set_title('title')

axes2.plot(x, y, 'g')
axes2.set_xlabel('x-values')
axes2.set_ylabel('y-values')
axes2.set_title("Title Inside")

plt.show()

# %% [markdown]
# ## 1.1 Simple Graphs

# %%
import matplotlib.pyplot as plt

# %%
days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

fig, ax = plt.subplots()

ax.plot(days, celsius_values)
#Setting the Figures 

ax.set(xlabel = "Days", 
       ylabel = "Temperature in Celsius",
       title = "Temperature Graph")

plt.show()

# %%
#next Method 

days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

plt.plot(days, celsius_values)

#Setting the Figures 
plt.xlabel("Days")
plt.ylabel("Temperature in Celsius")
plt.title("Temperature Graph")
plt.grid(True)


plt.show()

# %%
#next Method 

days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

plt.plot(days, celsius_values, marker = "x")

#Setting the Figures 
plt.xlabel("Days")
plt.ylabel("Temperature in Celsius")
plt.title("Temperature Graph")
plt.grid(True)


plt.show()

# %% [markdown]
# #### 1.2 Matplotlib Markers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#next Method 

days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

plt.plot(days, celsius_values, color = "g", marker = "D", markerfacecolor = 'r', markeredgecolor = 'r') # D for Diamond 

#Setting the Figures 
plt.xlabel("Days")
plt.ylabel("Temperature in Celsius")
plt.title("Temperature Graph")
plt.grid(True)


plt.show()

# %%
#next Method 

days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

plt.plot(days, celsius_values, color = "blue", marker = "D", markerfacecolor = 'r', markeredgecolor = 'r') # D for Diamond 

#Setting the Figures 
plt.xlabel("Days")
plt.ylabel("Temperature in Celsius")
plt.title("Temperature Graph")
plt.grid(True)


plt.show()

# %%
days = list(range(1, 9))
celsius_values = [25.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]

fig, ax = plt.subplots()

ax.plot(days, celsius_values, marker = "o",
       markerfacecolor = 'green',
       markeredgecolor = 'green')
#Setting the Figures 

ax.set(xlabel = "Days", 
       ylabel = "Temperature in Celsius",
       title = "Temperature Graph")

plt.grid(True)

plt.show()

# %% [markdown]
# #### Subplots

# %%
days = list(range(1, 9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]

fig, ax = plt.subplots() 

ax.set(xlabel = 'Days', 
       ylabel = "Temperature in Celsius",
       title = "Temperature Graph")

ax.plot(days, celsius_min, 
        days, celsius_min, "Dy",
        days, celsius_max,
        days, celsius_max,"or") #Dy = Diamond and yellow, or = circle and red 

plt.grid(True)
plt.show()

# %%
#Calling the Plots Separately 
days = list(range(1, 9))
celsius_min = [19.6, 24.1, 26.7, 28.3, 27.5, 30.5, 32.8, 33.1]
celsius_max = [24.8, 28.9, 31.3, 33.0, 34.9, 35.6, 38.4, 39.2]

fig, ax = plt.subplots() 

ax.set(xlabel = 'Days', 
       ylabel = "Temperature in Celsius",
       title = "Temperature Graph")

ax.plot(days, celsius_min)
ax.plot(days, celsius_min, "Dg")
ax.plot(days, celsius_max)
ax.plot(days, celsius_max, "xg")


plt.grid(True)
plt.show()

# %% [markdown]
# ### fill_between()

# %%
n = 256

x = np.linspace(-np.pi, np.pi, n, endpoint=True) #Linsapce---start, stop, num
y = np.sin(2*x)

fig, ax = plt.subplots()

ax.plot(x, y, color = 'green', alpha = 1.0)
ax.fill_between(x, 0, y, color = 'green', alpha = 0.3)

plt.grid()
plt.show()

# %%
x = np.array(range(-10, 10))
f = x**2

fig, ax = plt.subplots()

ax.plot(x, f, "g")
ax.fill_between(x, 100, f, color = 'g', alpha = 0.4)

ax.set_xlabel("x")
ax.set_ylabel("f")
ax.set_title("x**2")

plt.grid()
plt.show()

# %%
x = np.linspace(-10, 10, num = 100)
f = x**2

fig, ax = plt.subplots()

ax.plot(x, f, "g")
ax.fill_between(x, 100, f, color = 'blue', alpha = 0.4)

ax.set_xlabel("x")
ax.set_ylabel("f")
ax.set_title("x**2")

plt.grid()
plt.show()

# %% [markdown]
# ## MATPLOTLIB TUTORIAL: SPINES AND TICKS

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 70, endpoint=True)
F1 = np.sin(2* x)
F2 = (2*x**5 + 4*x**4- 4.8*x**3 + 1.2*x**2 + x + 1)*np.exp(-x**2)

fig, ax = plt.subplots()

ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data', 0))

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data', 0))

ax.plot(x, F1, x, F2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y = 2 * np.sin(x)

fig, (ax0, ax1, ax2) = plt.subplots(nrows=3)

ax0.plot(x, y)
ax0.set_title('Normal Spines')

ax1.plot(x, y)
ax1.set_title('Bottom-Left Spines')
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')

ax2.plot(x, y)
ax2.spines['left'].set_bounds(-1, 1)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')

plt.subplots_adjust(hspace=0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 50)
y = np.sin(x)
y2 = y + 0.1 * np.random.normal(size=x.shape)

fig, ax = plt.subplots()
ax.plot(x, y, 'k--')
ax.plot(x, y2, 'ro')

ax.set_xlim((0, 2 * np.pi))
ax.set_xticks([0, np.pi, 2 * np.pi])
ax.set_xticklabels(['0', '$\pi$', '2$\pi$'])

ax.set_ylim((-1.5, 1.5))
ax.set_yticks([-1, 0, 1])

ax.spines['left'].set_bounds(-1, 1)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

plt.show()

# %%
plt.savefig('linegraph.png')

# %%
x = [0, 1, 2, 3, 4]
y = [0, 2, 4, 6, 8]

plt.figure(figsize=(8, 5), dpi = 100)

plt.plot(x, y, label = '2x', color = 'red', linewidth=2, marker = '.', linestyle = "--", 
         markersize = 10, markeredgecolor='blue')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('x vs y graph', fontdict={'fontsize':"18", "fontname":"Comic Sans MS"})

plt.legend()

plt.show()

# %%
x = [0, 1, 2, 3, 4]
y = [0, 2, 4, 6, 8]

plt.figure(figsize=(8, 5), dpi = 100)

# plt.plot(x, y, label = '2x', color = 'red', linewidth=2, marker = '.', linestyle = "--", 
#          markersize = 10, markeredgecolor='blue')

plt.plot(x, y, 'b^--', label = '2x')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('x vs y graph', fontdict={'fontsize':"18", "fontname":"Comic Sans MS"})

plt.legend()

plt.show()

# %%
x = [0, 1, 2, 3, 4]
y = [0, 2, 4, 6, 8]

plt.figure(figsize=(8, 5), dpi = 100)

# plt.plot(x, y, label = '2x', color = 'red', linewidth=2, marker = '.', linestyle = "--", 
#          markersize = 10, markeredgecolor='blue')

plt.plot(x, y, 'b^--', label = '2x')
x2 = np.arange(0, 4.5, 0.5)

#First part of the graph
plt.plot(x2[:6], x2[:6]**2, 'r', label = "x^2") #The graph is square of x2

#Plot remainder of graph as dot
plt.plot(x2[5:], x2[5:]**2, 'r--') #The graph is square of x2

#Changing the Ticks of Axis
plt.xticks([0, 1, 2, 3, 4, 5])

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('x vs y graph', fontdict={'fontsize':"18", "fontname":"Comic Sans MS"})

plt.legend()
plt.grid()

plt.show()

# %%
#BarChart 
labels = ["A", "B", "C", "D"]
values = [1, 4, 5, 3]

plt.figure(figsize=(8, 6), dpi = 100)

bars = plt.bar(labels, values)

patterns = ['/', 'o', 'x', '*']

for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=400)

plt.show()

# %%
#Next Method
#BarChart 
labels = ["A", "B", "C", "D"]
values = [1, 4, 5, 3]

plt.figure(figsize=(8, 6), dpi = 100)

bars = plt.bar(labels, values, color = 'green')
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('x')
bars[3].set_hatch('*')

plt.savefig('barchart.png', dpi=400)

plt.show()

# %% [markdown]
# ### Real-world Exmaples

# %%
import pandas as pd

# %%
gas = pd.read_csv('E:\Python\Data\gas_prices.csv')
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas.tail()
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 14         4.51  5.56  1.88
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27

# %%
gas.shape
# Out:
# (19, 11)

# %%
gas.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
gas.describe(include='all')
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
plt.figure(figsize=(8, 5), dpi = 100)

plt.title("Gas Prices over Timie (in $)", fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label = "United Status")
plt.plot(gas.Year, gas.Canada, 'r.-')
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas.Australia, 'y.-')

plt.xticks(gas.Year[::3].tolist()+[2011])

plt.show()

# %%
plt.figure(figsize=(8, 5), dpi = 100)

plt.title("Gas Prices over Timie (in $)", fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label = "United States")
plt.plot(gas.Year, gas.Canada, 'r.-', label = "Canada")
plt.plot(gas.Year, gas['South Korea'], 'g.-', label = 'South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label = "Australia")

plt.xticks(gas.Year[::3].tolist()+[2011])
plt.xlabel("Year")
plt.ylabel("Price in $")
plt.title("Price of Gas")

plt.legend()
plt.grid()

plt.show()

# %%
plt.figure(figsize=(8, 5), dpi = 100)

plt.title("Gas Prices over Timie (in $)", fontdict={'fontweight':'bold', 'fontsize': 18})

#Plotting many values 
countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']

for country in gas:
    if country in countries_to_look_at:
        plt.plot(gas.Year, gas[country], marker = '.')

plt.xticks(gas.Year[::3].tolist()+[2011])
plt.xlabel("Year")
plt.ylabel("Price in $")
plt.title("Price of Gas")

plt.legend()


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8, 5), dpi = 100)

plt.title("Gas Prices over Timie (in $)", fontdict={'fontweight':'bold', 'fontsize': 18})

#All the countries in one graph

for country in gas:
    if country != "Year":
        plt.plot(gas.Year, gas[country], marker = '*')

plt.xticks(gas.Year[::3].tolist()+[2011])
plt.xlabel("Year")
plt.ylabel("Price in $")
plt.title("Price of Gas")

plt.legend()


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
new_gas = gas.dropna(axis=1)
new_gas
# Out:
#     Year  Canada  France  Germany  Italy  Japan  Mexico  South Korea    UK  \
# 0   1990    1.87    3.63     2.65   4.59   3.16    1.00         2.05  2.82
# 1   1991    1.92    3.45     2.90   4.50   3.46    1.30         2.49  3.01
# 2   1992    1.73    3.56     3.27   4.53   3.58    1.50         2.65  3.06
# 3   1993    1.57    3.41     3.07   3.68   4.16    1.56         2.88  2.84
# 4   1994    1.45    3.59     3.52   3.70   4.36    1.48         2.87  2.99
# 5   1995    1.53    4.26     3.96   4.00   4.43    1.11         2.94  3.21
# 6   1996    1.61    4.41     3.94   4.39   3.64    1.25         3.18  3.34
# 7   1997    1.62    4.00     3.53   4.07   3.26    1.47         3.34  3.83
# 8   1998    1.38    3.87     3.34   3.84   2.82    1.49         3.04  4.06
# 9   1999    1.52    3.85     3.42   3.87   3.27    1.79         3.80  4.29
# 10  2000    1.86    3.80     3.45   3.77   3.65    2.01         4.18  4.58
# ...

# %%
plt.figure(figsize=(8, 5))

plt.style.use('ggplot')

plt.hist(gas['Australia'], bins = 3, color = '#abab00')

plt.xticks([2, 3, 4, 5])

plt.xlabel("Gass Price in USD")
plt.ylabel("Frequency")
plt.title("Distribution of Gas Price in USD", fontname = 'Comic Sans MS')

plt.show()

# %%
fifa = pd.read_csv('E:\\Python\\Data\\fifa_data.csv')
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %% [markdown]
# #### Pie Chart

# %%
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

plt.figure(figsize=(6, 5))

labels = ['Left', 'Right']
colors = ['red', 'green']

plt.pie([left, right], labels=labels, colors = colors, autopct = '%.2f%%')

plt.title("Foot Preference of FIFA Players")

plt.show()
# Out:
# C:\Users\netra\AppData\Local\Temp\ipykernel_17860\2738574165.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
# C:\Users\netra\AppData\Local\Temp\ipykernel_17860\2738574165.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

# %%
left = fifa.loc[fifa['Preferred Foot']=='Left'].shape[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].shape[0]

plt.figure(figsize=(6, 5))
explode = (0.1, 0.2)
labels = ['Left', 'Right']
colors = ['red', 'green']

plt.pie([left, right], labels=labels, colors = colors, explode=explode, autopct = '%.2f%%')

plt.title("Foot Preference of FIFA Players")

plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [30, 20, 15, 10]
labels = ['A', 'B', 'C', 'D']
colors = ['red', 'green', 'blue', 'orange']
explode = (0.1, 0.1, 0, 0)

plt.figure(figsize=(6, 5))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', explode=explode)
plt.title("Exploded Pie Chart")
plt.show()

# %% [markdown]
# ### BoxPlot

# %%
new_gas.head()
# Out:
#    Year  Canada  France  Germany  Italy  Japan  Mexico  South Korea    UK  \
# 0  1990    1.87    3.63     2.65   4.59   3.16    1.00         2.05  2.82
# 1  1991    1.92    3.45     2.90   4.50   3.46    1.30         2.49  3.01
# 2  1992    1.73    3.56     3.27   4.53   3.58    1.50         2.65  3.06
# 3  1993    1.57    3.41     3.07   3.68   4.16    1.56         2.88  2.84
# 4  1994    1.45    3.59     3.52   3.70   4.36    1.48         2.87  2.99
#
#     USA
# 0  1.16
# 1  1.14
# 2  1.13
# 3  1.11
# 4  1.11

# %%
plt.figure(figsize=(8, 5), dpi = 100)

plt.boxplot(new_gas['Canada'])

plt.xlabel("Country: Canada")
plt.ylabel("Price in US $")

plt.legend()

plt.grid()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
fifa.shape
# Out:
# (18207, 89)

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
gas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         19 non-null     int64
#  1   Australia    18 non-null     float64
#  2   Canada       19 non-null     float64
#  3   France       19 non-null     float64
#  4   Germany      19 non-null     float64
#  5   Italy        19 non-null     float64
#  6   Japan        19 non-null     float64
#  7   Mexico       19 non-null     float64
#  8   South Korea  19 non-null     float64
#  9   UK           19 non-null     float64
#  10  USA          19 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 1.8 KB

# %%
for n in "Netra":
    print(n)
# Out:
# N
# e
# t
# r
# a

# %%
def netra(n):
    print(n)
netra("Netra Kumar Manandhar is a great personality and he is a great person in the world to know and unerstand. Thank you so much netra sir for this wonderfull session")
# Out:
# Netra Kumar Manandhar is a great personality and he is a great person in the world to know and unerstand. Thank you so much netra sir for this wonderfull session

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

w = 3
Y, X = np.mgrid[-w:w:100j, -w:w:100j]
U = -1 - X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

fig = plt.figure(figsize=(7, 9))
gs = gridspec.GridSpec(nrows=3, ncols=2, height_ratios=[1, 1, 2])

#  Varying density along a streamline
ax0 = fig.add_subplot(gs[0, 0])
ax0.streamplot(X, Y, U, V, density=[0.5, 1])
ax0.set_title('Varying Density')

# Varying color along a streamline
ax1 = fig.add_subplot(gs[0, 1])
strm = ax1.streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn')
fig.colorbar(strm.lines)
ax1.set_title('Varying Color')

#  Varying line width along a streamline
ax2 = fig.add_subplot(gs[1, 0])
lw = 5*speed / speed.max()
ax2.streamplot(X, Y, U, V, density=0.6, color='k', linewidth=lw)
ax2.set_title('Varying Line Width')

# Controlling the starting points of the streamlines
seed_points = np.array([[-2, -1, 0, 1, 2, -1], [-2, -1,  0, 1, 2, 2]])

ax3 = fig.add_subplot(gs[1, 1])
strm = ax3.streamplot(X, Y, U, V, color=U, linewidth=2,
                      cmap='autumn', start_points=seed_points.T)
fig.colorbar(strm.lines)
ax3.set_title('Controlling Starting Points')

# Displaying the starting points with blue symbols.
ax3.plot(seed_points[0], seed_points[1], 'bo')
ax3.set(xlim=(-w, w), ylim=(-w, w))

# Create a mask
mask = np.zeros(U.shape, dtype=bool)
mask[40:60, 40:60] = True
U[:20, :20] = np.nan
U = np.ma.array(U, mask=mask)

ax4 = fig.add_subplot(gs[2:, :])
ax4.streamplot(X, Y, U, V, color='r')
ax4.set_title('Streamplot with Masking')

ax4.imshow(~mask, extent=(-w, w, -w, w), alpha=0.5, cmap='gray', aspect='auto')
ax4.set_aspect('equal')

plt.tight_layout()
plt.show()
